# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
path=r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\data files\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
cat_columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
Bi Variate Analysis
~ We already seen Uni variate analysis
~  We performed the categorical columns analysis
    ~ frequency table(Value counts)
    ~ Bar charts
    ~ Relative frequency table(Value counts Normalized form)
    ~ Pie charts
~ We performed num columns analysis
    ~ Histogram
    ~ Distribution plots
    ~ Box plots
    ~ Outliers analysis
    ~ Filling the Outliers
** Now we will do Categorical -Categorical Analysis
**                  Numerical-Numerical analysis
**                  Categorical -Numerical Analysis

# %% [markdown]
#  $Categorical$  - $ Categorical$ $ Columns$

# %%
~ Lets consider two columns
    ~ Continent
    ~ Case status

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %% [markdown]
# ** Task **
# ~ Find the certified observations continent wise
# ~ Find the Denied observations continent wise

# %%
# step-1: Make first condition continent=='Asia'
# Step-2 : Make the Second condition case_status=='certified'
# step-3 : Make the third condition : con1& con2
# step-4 : Then retrieve dataframe and take the count

# %%
con1=visa_df['continent']=="Asia"
con2=visa_df['case_status']=="Certified"
con3=con1&con2
con3
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Length: 25480, dtype: bool

# %%
len(visa_df[con3])
# Out:
# 11012

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
continents=visa_df['continent'].unique()
certified_list=[]
denied_list=[]
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=="Certified"
    con3=visa_df['case_status']=="Denied"
    cert_con=con1&con2
    den_con=con1&con3
    cert_count=len(visa_df[cert_con])
    den_count=len(visa_df[den_con])
    #count=len(visa_df[con3])
    print(f"no.of certified visa from {i} is : {cert_count}")
    print(f"no.of denied visa from {i} is : {den_count}")
    certified_list.append(cert_count)
    denied_list.append(den_count)
# Out:
# no.of certified visa from Asia is : 11012
# no.of denied visa from Asia is : 5849
# no.of certified visa from Africa is : 397
# no.of denied visa from Africa is : 154
# no.of certified visa from North America is : 2037
# no.of denied visa from North America is : 1255
# no.of certified visa from Europe is : 2957
# no.of denied visa from Europe is : 775
# no.of certified visa from South America is : 493
# no.of denied visa from South America is : 359
# no.of certified visa from Oceania is : 122
# no.of denied visa from Oceania is : 70

# %%
certified_list
# Out:
# [11012, 397, 2037, 2957, 493, 122]

# %%
denied_list
# Out:
# [5849, 154, 1255, 775, 359, 70]

# %%
# df
continents
certified_list
cols=['Continents','Certified']
df1=pd.DataFrame(zip(continents,certified_list),
                columns=cols)
df1
# Out:
#       Continents  Certified
# 0           Asia      11012
# 1         Africa        397
# 2  North America       2037
# 3         Europe       2957
# 4  South America        493
# 5        Oceania        122

# %%
denied_list
# Out:
# [5849, 154, 1255, 775, 359, 70]

# %%
continents
denied_list
cols=['Continents','Denied']
df2=pd.DataFrame(zip(continents,denied_list),
                columns=cols)
df2
# Out:
#       Continents  Denied
# 0           Asia    5849
# 1         Africa     154
# 2  North America    1255
# 3         Europe     775
# 4  South America     359
# 5        Oceania      70

# %%
#pd.DataFrame(zip(continents,certified_list))

# %%
cols=['Certified','Denied']
df3=pd.DataFrame(zip(certified_list,denied_list),
                index=continents,
                columns=cols)
df3
# Out:
#                Certified  Denied
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %% [markdown]
#  $ Cross$  $ tab$

# %%
~ The above data frame we can make by using a method : ** cross tab**
~ It is available in pandas
~ It takes two arguments
    ~ index
    ~ column
~ In above data frame index column is : continent
~ in above data frame data column is : case_status

# %%
idx_column=visa_df['continent']
data_column=visa_df['case_status']
df4=pd.crosstab(visa_df['continent'],visa_df['case_status'])
df4
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
df3.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
#  $ Multivariant $  $ Analysis$

# %%
~ Education
~ continent
~case_status
~ we already know from Asia there 11k Accepted visa
~ In that I want further break down on education
~ Here also pd.cross tab
     ~ 1)st  fix your index of any one column out of 3 columns
    ~ then keep  two column in a list and pass as data column

# %%
idx_column=visa_df['continent']
data_column=[visa_df['education_of_employee'],visa_df['case_status']]
df5=pd.crosstab(idx_column,data_column)
df5
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# $Numerical$ $ VS$ $ Numerical$

# %%
~ To understand NUmerical columns relation we need to plot scatter plots
~ Scatter plots gives relation between two num columns
~ bar chart-pie chart-histogram-scatter plots
~ scatters plot under matplotlib package
~ plt.scatter

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.scatter(x,y)
plt.plot(x,y)

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# step-1: read one num column
# step-2: read another num column
# step-3: apply scatter plots
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
col3=visa_df['prevailing_wage']
plt.figure(figsize=(14,4))
plt.subplot(1,3,1).scatter(col1,col2)
plt.xlabel('no_of_employees')
plt.ylabel('yr_of_estab')  
plt.subplot(1,3,2).scatter(col1,col3)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
plt.subplot(1,3,3).scatter(col2,col3)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
              
#plt.scatter(col1,col2)
#plt.plot(col1,col2)
# Out:
# Text(0, 0.5, 'prevailing_wage')

# %%
~ implement covariance function
~ Covariance vs correlation
    ~ Covariance will tell about columns have rlation or not
    ~ Covariance will explain about relation status
        ~ Positive relation
        ~ negative relation
        ~ no relation
    ~ Correlation tells about how much relation between two variables
    ~ It denotes with 'r'
    ~ r varies from -1 to 1
    ~ -1 to 0 indicates negative relation quantity
    ~ 0 to 1 indicates positive relation quantity
    ~ 0 indicates no relation

# %% [markdown]
# $method$ $name$:   $corr$

# %%
visa_df.corr(numeric_only=True)#  1,1,1 in diagoanl i.e   variance
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
#  $ HEAT $  $MAP$

# %%
~ Heat map is one of the important visualization method, to show the matrix 
~ It is under Seaborn package
~ In every matrix we have heighest values and lowest values available
~ Heat map will provide colour visualiztion
~ Also it provides color bar, which colour indicates which value

# %%
corr_data=visa_df.corr(numeric_only=True)#  1,1,1 in diagoanl i.e   variance
sns.heatmap(corr_data,annot=True)# annotations will give color numbers
plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)#  1,1,1 in diagoanl i.e   variance
sns.heatmap(corr_data,annot=True,cmap='ma')# annotations will give color numbers
plt.show()

# %%
~ By seeing the Graphs we might not say the relation status
~  It is best practice get the percentage of relation using correlation
~ All 3 columns having approximately 0 percen of relation
~ which indicates all columns having no relation
~ no relation means independent each other
~ In ML we expect input columns should be independent each other
~ Correlation method gives matrix view
~ We have 3 columns 3*3 total 9 fields
~ If a data has 20 columns then 20*20 total 400 fields
~ thats why always go with Heat map visualization
